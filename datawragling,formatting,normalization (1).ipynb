# %%
# !pip install pandas

# %%
import pandas as pd
df = pd.read_csv("Data1.csv")
df.head()
# Out:
#        date  cases  active cases  deaths
# 0  15/02/20   16.0          13.0    -1.0
# 1  16/02/20   16.0          13.0     0.0
# 2  17/02/20    NaN           9.0     0.0
# 3  18/02/20   16.0           7.0     0.0
# 4  19/02/20   16.0           7.0     NaN

# %%
df.dropna(axis=0, inplace=False)
# Out:
#         date     cases  active cases  deaths
# 0   15/02/20      16.0          13.0    -1.0
# 1   16/02/20      16.0          13.0     0.0
# 3   18/02/20      16.0           7.0     0.0
# 5   20/02/20      16.0           3.0     0.0
# 6   21/02/20      16.0           2.0     0.0
# 7   22/02/20      16.0           2.0     0.0
# 8   23/02/20      16.0           2.0     0.0
# 9   24/02/20      16.0           2.0     0.0
# 10  25/02/20      18.0           3.0     0.0
# 12  27/02/20      48.0          32.0     0.0
# 13  28/02/20      74.0          58.0     0.0
# 14  29/02/20      79.0          63.0     0.0
# 15  01/03/20     130.0         114.0     0.0
# 16  02/03/20     165.0         149.0     0.0
# 17  03/03/20     203.0         187.0     0.0
# 18  04/03/20     262.0         246.0     0.0
# 21  07/03/20     800.0         782.0     0.0
# 22  08/03/20    1040.0        1022.0     0.0
# 23  09/03/20    1224.0        1204.0     2.0
# 24  10/03/20    1565.0        1545.0     2.0
# ...

# %%
df.dropna(axis=0, subset = ['deaths'])
# Out:
#         date     cases  active cases  deaths
# 0   15/02/20      16.0          13.0    -1.0
# 1   16/02/20      16.0          13.0     0.0
# 2   17/02/20       NaN           9.0     0.0
# 3   18/02/20      16.0           7.0     0.0
# 5   20/02/20      16.0           3.0     0.0
# ..       ...       ...           ...     ...
# 59  14/04/20  132210.0       60515.0  3495.0
# 60  15/04/20  134753.0       58349.0  3804.0
# 61  16/04/20  137698.0       56646.0  4052.0
# 62  17/04/20  141397.0       53931.0  4352.0
# 63  18/04/20  143724.0       53786.0  4538.0
#
# [63 rows x 4 columns]

# %%
df.dropna(axis=0, subset = ['deaths'],inplace=True)
df
# Out:
#         date     cases  active cases  deaths
# 0   15/02/20      16.0          13.0    -1.0
# 1   16/02/20      16.0          13.0     0.0
# 2   17/02/20       NaN           9.0     0.0
# 3   18/02/20      16.0           7.0     0.0
# 5   20/02/20      16.0           3.0     0.0
# ..       ...       ...           ...     ...
# 59  14/04/20  132210.0       60515.0  3495.0
# 60  15/04/20  134753.0       58349.0  3804.0
# 61  16/04/20  137698.0       56646.0  4052.0
# 62  17/04/20  141397.0       53931.0  4352.0
# 63  18/04/20  143724.0       53786.0  4538.0
#
# [63 rows x 4 columns]

# %%
df['cases'].fillna(value=10,inplace=True)

# %%
df
# Out:
#         date     cases  active cases  deaths
# 0   15/02/20      16.0          13.0    -1.0
# 1   16/02/20      16.0          13.0     0.0
# 2   17/02/20      10.0           9.0     0.0
# 3   18/02/20      16.0           7.0     0.0
# 5   20/02/20      16.0           3.0     0.0
# ..       ...       ...           ...     ...
# 59  14/04/20  132210.0       60515.0  3495.0
# 60  15/04/20  134753.0       58349.0  3804.0
# 61  16/04/20  137698.0       56646.0  4052.0
# 62  17/04/20  141397.0       53931.0  4352.0
# 63  18/04/20  143724.0       53786.0  4538.0
#
# [63 rows x 4 columns]

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('Data1.csv')
mean=df['deaths'].mean()
df['deaths'].replace(np.nan, mean, inplace=True)
df
# Out:
#         date     cases  active cases       deaths
# 0   15/02/20      16.0          13.0    -1.000000
# 1   16/02/20      16.0          13.0     0.000000
# 2   17/02/20       NaN           9.0     0.000000
# 3   18/02/20      16.0           7.0     0.000000
# 4   19/02/20      16.0           7.0   809.206349
# ..       ...       ...           ...          ...
# 59  14/04/20  132210.0       60515.0  3495.000000
# 60  15/04/20  134753.0       58349.0  3804.000000
# 61  16/04/20  137698.0       56646.0  4052.000000
# 62  17/04/20  141397.0       53931.0  4352.000000
# 63  18/04/20  143724.0       53786.0  4538.000000
#
# [64 rows x 4 columns]

# %%
df['deaths']=df['deaths']-100
df
# Out:
#         date     cases  active cases       deaths
# 0   15/02/20      16.0          13.0  -101.000000
# 1   16/02/20      16.0          13.0  -100.000000
# 2   17/02/20       NaN           9.0  -100.000000
# 3   18/02/20      16.0           7.0  -100.000000
# 4   19/02/20      16.0           7.0   709.206349
# ..       ...       ...           ...          ...
# 59  14/04/20  132210.0       60515.0  3395.000000
# 60  15/04/20  134753.0       58349.0  3704.000000
# 61  16/04/20  137698.0       56646.0  3952.000000
# 62  17/04/20  141397.0       53931.0  4252.000000
# 63  18/04/20  143724.0       53786.0  4438.000000
#
# [64 rows x 4 columns]

# %%
df.rename(columns={'deaths':'updated deaths'},inplace=True)
df
# Out:
#         date     cases  active cases  updated deaths
# 0   15/02/20      16.0          13.0     -101.000000
# 1   16/02/20      16.0          13.0     -100.000000
# 2   17/02/20       NaN           9.0     -100.000000
# 3   18/02/20      16.0           7.0     -100.000000
# 4   19/02/20      16.0           7.0      709.206349
# ..       ...       ...           ...             ...
# 59  14/04/20  132210.0       60515.0     3395.000000
# 60  15/04/20  134753.0       58349.0     3704.000000
# 61  16/04/20  137698.0       56646.0     3952.000000
# 62  17/04/20  141397.0       53931.0     4252.000000
# 63  18/04/20  143724.0       53786.0     4438.000000
#
# [64 rows x 4 columns]

# %%
df['updated deaths'].tail()
# Out:
# 59    3395.0
# 60    3704.0
# 61    3952.0
# 62    4252.0
# 63    4438.0
# Name: updated deaths, dtype: float64

# %%
df['updated deaths']=df['updated deaths'].astype(int)
df['date']=pd.to_datetime(df['date'])
df
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_5888\2510682537.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date']=pd.to_datetime(df['date'])
#          date     cases  active cases  updated deaths
# 0  2020-02-15      16.0          13.0            -101
# 1  2020-02-16      16.0          13.0            -100
# 2  2020-02-17       NaN           9.0            -100
# 3  2020-02-18      16.0           7.0            -100
# 4  2020-02-19      16.0           7.0             709
# ..        ...       ...           ...             ...
# 59 2020-04-14  132210.0       60515.0            3395
# 60 2020-04-15  134753.0       58349.0            3704
# 61 2020-04-16  137698.0       56646.0            3952
# 62 2020-04-17  141397.0       53931.0            4252
# 63 2020-04-18  143724.0       53786.0            4438
#
# [64 rows x 4 columns]

# %%
df = pd.DataFrame({'Height':[6,3,4,6.2,8],
                     
                   'Weight':[75,40,56,200,58]})
  
display(df)
# Out:
#    Height  Weight
# 0     6.0      75
# 1     3.0      40
# 2     4.0      56
# 3     6.2     200
# 4     8.0      58

# %%
df['Weight']=df['Weight']/df['Weight'].max()
df
# Out:
#    Height  Weight
# 0     6.0   0.375
# 1     3.0   0.200
# 2     4.0   0.280
# 3     6.2   1.000
# 4     8.0   0.290

# %%
df = pd.DataFrame({'Height':[6,3,4,6.2,8],
                     
                   'Weight':[75,40,56,200,58]})
print(df)
df['Weight']=(df['Weight']-df['Weight'].min())/(df['Weight'].max()-df['Weight'].min())
# Out:
#    Height  Weight
# 0     6.0      75
# 1     3.0      40
# 2     4.0      56
# 3     6.2     200
# 4     8.0      58

# %%
df
# Out:
#    Height   Weight
# 0     6.0  0.21875
# 1     3.0  0.00000
# 2     4.0  0.10000
# 3     6.2  1.00000
# 4     8.0  0.11250

# %%
df = pd.DataFrame({'Height':[6,3,4,6.2,8],
                     
                   'Weight':[75,40,56,200,58]})

df['Weight']=(df['Weight']-df['Weight'].mean())/(df['Weight'].std())

# %%
df
# Out:
#    Height    Weight
# 0     6.0 -0.166071
# 1     3.0 -0.704265
# 2     4.0 -0.458234
# 3     6.2  1.756050
# 4     8.0 -0.427480
