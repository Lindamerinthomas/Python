# %%
import sqlite3

# Create a SQL connection to our SQLite database
con = sqlite3.connect("chinook.db")

cur = con.cursor()

# The result of a "cursor.execute" can be iterated over by row
for row in cur.execute('SELECT * FROM Census_Data;'):
    print(row)
  

# Be sure to close the connection
con.close()
# Out:
# (1, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39)
# (2, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46)
# (3, 'Uptown', 3.8, 24, 8.9, 11.8, 22.2, 35787, 20)
# (4, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17)
# (5, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6)
# (6, 'Lake View', 1.1, 11.4, 4.7, 2.6, 17, 60058, 5)
# (7, 'Lincoln Park', 0.8, 12.3, 5.1, 3.6, 21.5, 71551, 2)
# (8, 'Near North Side', 1.9, 12.9, 7, 2.5, 22.6, 88669, 1)
# (9, 'Edison Park', 1.1, 3.3, 6.5, 7.4, 35.3, 40959, 8)
# (10, 'Norwood Park', 2.0, 5.4, 9, 11.5, 39.5, 32875, 21)
# (11, 'Jefferson Park', 2.7, 8.6, 12.4, 13.4, 35.5, 27751, 25)
# (12, 'Forest Glen', 1.1, 7.5, 6.8, 4.9, 40.5, 44164, 11)
# (13, 'North Park', 3.9, 13.2, 9.9, 14.4, 39, 26576, 33)
# (14, 'Albany Park', 11.3, 19.2, 10, 32.9, 32, 21323, 53)
# (15, 'Portage Park', 4.1, 11.6, 12.6, 19.3, 34, 24336, 35)
# (16, 'Irving Park', 6.3, 13.1, 10, 22.4, 31.6, 27249, 34)
# (17, 'Dunning', 5.2, 10.6, 10, 16.2, 33.6, 26282, 28)
# ...

# %%
con = sqlite3.connect("chinook.db")
cur = con.cursor()
cur.execute('''
          INSERT INTO Census_Data (COMMUNITY_AREA_NUMBER,COMMUNITY_AREA_NAME )
          VALUES
                (78, 'Lakeshore')               
          ''')

for row in cur.execute('SELECT * FROM Census_Data;'):
    print(row)

# Be sure to close the connection
con.close()
# Out:
# (1, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39)
# (2, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46)
# (3, 'Uptown', 3.8, 24, 8.9, 11.8, 22.2, 35787, 20)
# (4, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17)
# (5, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6)
# (6, 'Lake View', 1.1, 11.4, 4.7, 2.6, 17, 60058, 5)
# (7, 'Lincoln Park', 0.8, 12.3, 5.1, 3.6, 21.5, 71551, 2)
# (8, 'Near North Side', 1.9, 12.9, 7, 2.5, 22.6, 88669, 1)
# (9, 'Edison Park', 1.1, 3.3, 6.5, 7.4, 35.3, 40959, 8)
# (10, 'Norwood Park', 2.0, 5.4, 9, 11.5, 39.5, 32875, 21)
# (11, 'Jefferson Park', 2.7, 8.6, 12.4, 13.4, 35.5, 27751, 25)
# (12, 'Forest Glen', 1.1, 7.5, 6.8, 4.9, 40.5, 44164, 11)
# (13, 'North Park', 3.9, 13.2, 9.9, 14.4, 39, 26576, 33)
# (14, 'Albany Park', 11.3, 19.2, 10, 32.9, 32, 21323, 53)
# (15, 'Portage Park', 4.1, 11.6, 12.6, 19.3, 34, 24336, 35)
# (16, 'Irving Park', 6.3, 13.1, 10, 22.4, 31.6, 27249, 34)
# (17, 'Dunning', 5.2, 10.6, 10, 16.2, 33.6, 26282, 28)
# ...

# %%
# %load_ext sql
# %sql sqlite:///chinook.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# !pip install sqlalchemy==1.3.9
# !pip install ibm_db_sa
# !pip install ipython-sql
# Out:
# ...
#   Using cached SQLAlchemy-1.3.9-cp311-cp311-win_amd64.whl
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.22
#     Uninstalling SQLAlchemy-2.0.22:
#       Successfully uninstalled SQLAlchemy-2.0.22
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.3.9 which is incompatible.
# ...
#   Obtaining dependency information for sqlalchemy>=2.0 from https://files.pythonhosted.org/packages/04/88/39f1f5570eb1d28704b4954c97ee91c3b5604f2949ab8ed40b33c90aaad9/SQLAlchemy-2.0.22-cp311-cp311-win_amd64.whl.metadata
#   Using cached SQLAlchemy-2.0.22-cp311-cp311-win_amd64.whl.metadata (9.7 kB)
# ...
# Using cached SQLAlchemy-2.0.22-cp311-cp311-win_amd64.whl (2.1 MB)
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.9
# ...

# %%
# %load_ext sql
# %sql sqlite:///chinook.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# SELECT
#     name
# FROM
#     sqlite_master
# WHERE
#     type='table'
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Movies',),
#  ('Chicago_Public_Schools',),
#  ('Chicago_Crime_Data',),
#  ('Census_Data',)]

# %%
# %sql SELECT * from Movies
# Out:
#  * sqlite:///chinook.db
# Done.
# [(901, 'Vertigo', 1958, 128, 'English', '1958-08-24', 'UK', 'Righty Sock', 9001, '8.4', '263575', None, None, None, None, None),
#  (902, 'The Innocents', 1961, 100, 'English', '1962-02-19', 'SW', 'Jack Malvern', 9002, '7.9', '20207', None, None, None, None, None),
#  (903, 'Lawrence of Arabia', 1962, 216, 'English', '1962-12-11', 'UK', 'Flagrant Baronessa', 9003, '8.3', '202778', None, None, None, None, None),
#  (904, 'The Deer Hunter', 1978, 183, 'English', '1979-03-08', 'UK', 'Alec Shaw', 9005, '8.2', '484746', None, None, None, None, None),
#  (905, 'Amadeus', 1984, 160, 'English', '1985-01-07', 'UK', 'Francois Truffaut', 9006, '7.3', None, None, None, None, None, None),
#  (906, 'Blade Runner', 1982, 117, 'English', '1982-09-09', 'UK', 'Victor Woeltjen', 9007, '8.6', '779489', None, None, None, None, None),
#  (907, 'Eyes Wide Shut', 1999, 159, 'English', None, 'UK', 'Simon Wright', 9008, None, '227235', None, None, None, None, None),
# ...

# %%
# %sql select count(*) as total_crimes from chicago_crime_data
# Out:
#  * sqlite:///chinook.db
# Done.
# [(533,)]

# %%
# %%sql
#
# CREATE TABLE Fam(Name TEXT, Age INTEGER, Profession TEXT, Major TEXT);
# INSERT INTO Fam (Name, Age) VALUES('Pam', 50);
# INSERT INTO Fam (Name, Age) VALUES('Miranda', 32);
# INSERT INTO Fam (Name, Age) VALUES('Pascal', 45);
# INSERT INTO Fam (Name, Age) VALUES('Dave', 12);
# INSERT INTO Fam (Name, Age) VALUES('Emmy', 23);
#
# UPDATE Fam SET Profession='Unknown' WHERE Profession ISNULL
# Out:
#  * sqlite:///chinook.db
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 5 rows affected.
# []

# %%
# %%sql
# SELECT
#     name
# FROM
#     sqlite_master
# WHERE
#     type='table'
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Movies',),
#  ('Chicago_Public_Schools',),
#  ('Chicago_Crime_Data',),
#  ('Census_Data',),
#  ('Fam',)]

# %%
import pandas as pd
result = %sql select * from movies
dataframe = result.DataFrame()
dataframe
# Out:
#  * sqlite:///chinook.db
# Done.
#     mov_id                  mov_name  mov_year  mov_time  mov_lang  \
# 0      901                   Vertigo      1958       128   English
# 1      902             The Innocents      1961       100   English
# 2      903        Lawrence of Arabia      1962       216   English
# 3      904           The Deer Hunter      1978       183   English
# 4      905                   Amadeus      1984       160   English
# 5      906              Blade Runner      1982       117   English
# 6      907            Eyes Wide Shut      1999       159   English
# 7      908        The Usual Suspects      1995       106   English
# 8      909                 Chinatown      1974       130   English
# 9      910             Boogie Nights      1997       155   English
# 10     911                Annie Hall      1977        93   English
# 11     912         Princess Mononoke      1997       134  Japanese
# ...

# %% [markdown]
# Find the total number of crimes recorded in the CRIME table

# %%
# %sql select count(*) as total_crimes from chicago_crime_data
# Out:
#  * sqlite:///chinook.db
# Done.
# [(533,)]

# %%
List community areas with per capita income less than 11000.

# %%
# %sql select community_area_name, per_capita_income from Census_data where per_capita_income < 11000;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('West Garfield Park', 10934),
#  ('South Lawndale', 10402),
#  ('Fuller Park', 10432),
#  ('Riverdale', 8201)]

# %%
# %sql select community_area_name, per_capita_income from Census_data where per_capita_income < 11000;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('West Garfield Park', 10934),
#  ('South Lawndale', 10402),
#  ('Fuller Park', 10432),
#  ('Riverdale', 8201)]

# %%
List all case numbers for crimes involving minors?(children are not considered minors for the purposes of crime analysis)

# %%
# %sql SELECT CASE_NUMBER FROM CHICAGO_CRIME_DATA WHERE DESCRIPTION LIKE '%MINOR%'
# Out:
#  * sqlite:///chinook.db
# Done.
# [('HL266884',), ('HK238408',)]

# %%
List all kidnapping crimes involving a child?

# %%
# %sql SELECT CASE_NUMBER, PRIMARY_TYPE, DATE, DESCRIPTION FROM CHICAGO_CRIME_DATA WHERE PRIMARY_TYPE='KIDNAPPING'
# Out:
#  * sqlite:///chinook.db
# Done.
# [('HN144152', 'KIDNAPPING', '01/26/2007 10:05:00 AM', 'CHILD ABDUCTION/STRANGER')]

# %%
What kinds of crimes were recorded at schools?

# %%
# %sql SELECT DISTINCT(PRIMARY_TYPE), LOCATION_DESCRIPTION FROM CHICAGO_CRIME_DATA WHERE LOCATION_DESCRIPTION LIKE '%SCHOOL%'
# Out:
#  * sqlite:///chinook.db
# Done.
# [('BATTERY', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('BATTERY', 'SCHOOL, PUBLIC, BUILDING'),
#  ('CRIMINAL DAMAGE', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'SCHOOL, PUBLIC, BUILDING'),
#  ('ASSAULT', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('CRIMINAL TRESPASS', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('PUBLIC PEACE VIOLATION', 'SCHOOL, PRIVATE, BUILDING'),
#  ('PUBLIC PEACE VIOLATION', 'SCHOOL, PUBLIC, BUILDING')]

# %%
List the average safety score for each type of school.

# %%
# %sql SELECT "ElementaryMiddleorHighSchool", AVG(SAFETY_SCORE) AVERAGE_SAFETY_SCORE FROM CHICAGO_PUBLIC_SCHOOLS GROUP BY "ElementaryMiddleorHighSchool";
# Out:
#  * sqlite:///chinook.db
# Done.
# [('ES', 49.52038369304557), ('HS', 49.62352941176471), ('MS', 48.0)]

# %%
List 5 community areas with highest % of households below poverty line

# %%
# %sql SELECT COMMUNITY_AREA_NAME, PERCENTHOUSEHOLDSBELOWPOVERTY FROM CENSUS_DATA ORDER BY PERCENTHOUSEHOLDSBELOWPOVERTY DESC LIMIT 5 ;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %%
Which community area is most crime prone

# %%
# %sql SELECT COMMUNITY_AREA_NUMBER ,COUNT(COMMUNITY_AREA_NUMBER) AS count FROM CHICAGO_CRIME_DATA GROUP BY COMMUNITY_AREA_NUMBER ORDER BY COUNT(COMMUNITY_AREA_NUMBER) DESC LIMIT 1;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(25, 43)]

# %%
# %sql SELECT COMMUNITY_AREA_NUMBER ,COUNT(COMMUNITY_AREA_NUMBER) AS count FROM CHICAGO_CRIME_DATA GROUP BY COMMUNITY_AREA_NUMBER ORDER BY COUNT(COMMUNITY_AREA_NUMBER) DESC LIMIT 1;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(25, 43)]

# %%
Use a sub-query to find the name of the community area with highest hardship index

# %%
# %sql SELECT COMMUNITY_AREA_NAME FROM  CENSUS_DATA WHERE HARDSHIP_INDEX = (SELECT MAX(HARDSHIP_INDEX) FROM CENSUS_DATA);
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Riverdale',)]

# %%
Use a sub-query to determine the Community Area Name with most number of crimes

# %%
# %sql SELECT community_area_name FROM CENSUS_DATA WHERE community_area_number = (SELECT community_area_number FROM CHICAGO_CRIME_DATA GROUP BY community_area_number ORDER BY COUNT(community_area_number) DESC LIMIT 1) LIMIT 1;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Austin',)]

# %%
# %sql SELECT community_area_name FROM CENSUS_DATA WHERE community_area_number = (SELECT community_area_number FROM CHICAGO_CRIME_DATA GROUP BY community_area_number ORDER BY COUNT(community_area_number) DESC LIMIT 1) LIMIT 1;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Austin',)]
